# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\korat\anaconda3\lib\site-packages (5.5.4)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\korat\anaconda3\lib\site-packages (from transformers) (1.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\korat\anaconda3\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\korat\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\korat\anaconda3\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\korat\anaconda3\lib\site-packages (from transformers) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\korat\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\korat\anaconda3\lib\site-packages (from transformers) (0.17.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\korat\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\korat\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\korat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\korat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\korat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\korat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\korat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\korat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\users\korat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\korat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\korat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\korat\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: colorama in c:\users\korat\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\korat\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\korat\anaconda3\lib\site-packages (from typer->transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\korat\anaconda3\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\korat\anaconda3\lib\site-packages (from typer->transformers) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\korat\anaconda3\lib\site-packages (from rich>=10.11.0->typer->transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\korat\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\korat\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers) (0.1.2)

# %%
# !pip install "transformers[torch]"
# Out:
# Requirement already satisfied: transformers[torch] in c:\users\korat\anaconda3\lib\site-packages (5.5.4)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\korat\anaconda3\lib\site-packages (from transformers[torch]) (1.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\korat\anaconda3\lib\site-packages (from transformers[torch]) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\korat\appdata\roaming\python\python313\site-packages (from transformers[torch]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\korat\anaconda3\lib\site-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\korat\anaconda3\lib\site-packages (from transformers[torch]) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\korat\anaconda3\lib\site-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: typer in c:\users\korat\anaconda3\lib\site-packages (from transformers[torch]) (0.17.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\korat\anaconda3\lib\site-packages (from transformers[torch]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\korat\anaconda3\lib\site-packages (from transformers[torch]) (4.67.1)
# Requirement already satisfied: torch>=2.4 in c:\users\korat\anaconda3\lib\site-packages (from transformers[torch]) (2.11.0)
# Requirement already satisfied: accelerate>=1.1.0 in c:\users\korat\anaconda3\lib\site-packages (from transformers[torch]) (1.13.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\korat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\korat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\korat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\korat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\korat\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.15.0)
# Requirement already satisfied: anyio in c:\users\korat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.10.0)
# Requirement already satisfied: certifi in c:\users\korat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\korat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.0.9)
# Requirement already satisfied: idna in c:\users\korat\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\korat\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.16.0)
# Requirement already satisfied: psutil in c:\users\korat\appdata\roaming\python\python313\site-packages (from accelerate>=1.1.0->transformers[torch]) (7.0.0)
# Requirement already satisfied: setuptools<82 in c:\users\korat\anaconda3\lib\site-packages (from torch>=2.4->transformers[torch]) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\korat\anaconda3\lib\site-packages (from torch>=2.4->transformers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\korat\anaconda3\lib\site-packages (from torch>=2.4->transformers[torch]) (3.5)
# Requirement already satisfied: jinja2 in c:\users\korat\anaconda3\lib\site-packages (from torch>=2.4->transformers[torch]) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\korat\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=2.4->transformers[torch]) (1.3.0)
# Requirement already satisfied: colorama in c:\users\korat\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers[torch]) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\korat\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\korat\anaconda3\lib\site-packages (from jinja2->torch>=2.4->transformers[torch]) (3.0.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\korat\anaconda3\lib\site-packages (from typer->transformers[torch]) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\korat\anaconda3\lib\site-packages (from typer->transformers[torch]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\korat\anaconda3\lib\site-packages (from typer->transformers[torch]) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\korat\anaconda3\lib\site-packages (from rich>=10.11.0->typer->transformers[torch]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\korat\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->typer->transformers[torch]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\korat\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers[torch]) (0.1.2)

# %%
import pandas as pd
from transformers import T5Tokenizer, T5ForConditionalGeneration ,Trainer, TrainingArguments

# %%
train_data=pd.read_csv("samsum-train.csv")
val_data=pd.read_csv("samsum-validation.csv")

# %%
train_data.head()
# Out:
#          id                                           dialogue  \
# 0  13818513  Amanda: I baked  cookies. Do you want some?\r\...
# 1  13728867  Olivia: Who are you voting for in this electio...
# 2  13681000  Tim: Hi, what's up?\r\nKim: Bad mood tbh, I wa...
# 3  13730747  Edward: Rachel, I think I'm in ove with Bella....
# 4  13728094  Sam: hey  overheard rick say something\r\nSam:...
#
#                                              summary
# 0  Amanda baked cookies and will bring Jerry some...
# 1  Olivia and Olivier are voting for liberals in ...
# 2  Kim may try the pomodoro technique recommended...
# 3  Edward thinks he is in love with Bella. Rachel...
# 4  Sam is confused, because he overheard Rick com...

# %%
train_data["dialogue"][0]
# Out:
# "Amanda: I baked  cookies. Do you want some?\r\nJerry: Sure!\r\nAmanda: I'll bring you tomorrow :-)"

# %%
train_data.shape
# Out:
# (14732, 3)

# %%
val_data.shape
# Out:
# (818, 3)

# %%
train_data.isnull().sum()
# Out:
# id          0
# dialogue    1
# summary     0
# dtype: int64

# %%
#random sampling
train_data=train_data.sample(n=4000,random_state=42).reset_index(drop=True)
val_data=val_data.sample(n=500,random_state=42).reset_index(drop=True)

# %%
train_data.shape
val_data.shape
# Out:
# (500, 3)

# %% [markdown]
# Data Pre-processing

# %%
import re

def clean_data(text):
    text=re.sub(r"\r\n"," ",text)
    text=re.sub(r"\s+"," ",text)
    text=re.sub(r"<.*?>"," ",text)
    text= text.strip().lower()
    return text

# %%
train_data['dialogue']=train_data['dialogue'].apply(clean_data)
train_data['summary']=train_data['summary'].apply(clean_data)

val_data['dialogue']=val_data['dialogue'].apply(clean_data)
val_data['summary']=val_data['summary'].apply(clean_data)

# %%
train_data['dialogue'][0]
# Out:
# "violet: hi! i came across this austin's article and i thought that you might find it interesting violet: claire: hi! :) thanks, but i've already read it. :) claire: but thanks for thinking about me :)"

# %%
len(train_data[0]['input_ids'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\korat\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 len(train_data[0]['input_ids'])
#
# File c:\Users\korat\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\korat\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 0
